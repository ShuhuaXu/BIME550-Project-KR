# %%
# Import required libraries
import pandas as pd
import requests
import os
import subprocess


def ensure_file_exists(url: str, file_path: str):
    if os.path.exists(file_path):
        print(f"File already exists at: {file_path}")
        return

    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    cmd = [
        "wget",
        "-c",  # resume if interrupted
        "-O",
        file_path,  # output file
        url,
    ]

    print("Downloading with wget...")
    subprocess.run(cmd, check=True)
    print("Download complete.")

# %%
# Configuration: Define file paths and API endpoints
GDC_CASE_NUMBER_URL = "https://api.gdc.cancer.gov/cases"
MAF_FILE_URL = "https://api.gdc.cancer.gov/data/1c8cfe5f-e52d-41ba-94da-f15ea1337efc"
MAF_FILE_PATH = "./data/mc3.v0.2.8.PUBLIC.maf.gz"
TCGA_BRCA_SAVE_PATH = "./results/TCGA_BRCA.csv"

# check if the MAF file has been downloaded
# if not, this funciton will download
ensure_file_exists(MAF_FILE_URL, MAF_FILE_PATH)

# Preview the MAF file structure by loading just the first row
# This helps us understand the available columns before loading the full dataset
maf_preview = pd.read_csv(MAF_FILE_PATH, sep="\t", comment="#", nrows=1)
print(maf_preview.columns.tolist())
# Out:
# File already exists at: ./data/mc3.v0.2.8.PUBLIC.maf.gz
# ['Hugo_Symbol', 'Entrez_Gene_Id', 'Center', 'NCBI_Build', 'Chromosome', 'Start_Position', 'End_Position', 'Strand', 'Variant_Classification', 'Variant_Type', 'Reference_Allele', 'Tumor_Seq_Allele1', 'Tumor_Seq_Allele2', 'dbSNP_RS', 'dbSNP_Val_Status', 'Tumor_Sample_Barcode', 'Matched_Norm_Sample_Barcode', 'Match_Norm_Seq_Allele1', 'Match_Norm_Seq_Allele2', 'Tumor_Validation_Allele1', 'Tumor_Validation_Allele2', 'Match_Norm_Validation_Allele1', 'Match_Norm_Validation_Allele2', 'Verification_Status', 'Validation_Status', 'Mutation_Status', 'Sequencing_Phase', 'Sequence_Source', 'Validation_Method', 'Score', 'BAM_File', 'Sequencer', 'Tumor_Sample_UUID', 'Matched_Norm_Sample_UUID', 'HGVSc', 'HGVSp', 'HGVSp_Short', 'Transcript_ID', 'Exon_Number', 't_depth', 't_ref_count', 't_alt_count', 'n_depth', 'n_ref_count', 'n_alt_count', 'all_effects', 'Allele', 'Gene', 'Feature', 'Feature_type', 'Consequence', 'cDNA_position', 'CDS_position', 'Protein_position', 'Amino_acids', 'Codons', 'Existing_variation', 'ALLELE_NUM', 'DISTANCE', 'STRAND', 'SYMBOL', 'SYMBOL_SOURCE', 'HGNC_ID', 'BIOTYPE', 'CANONICAL', 'CCDS', 'ENSP', 'SWISSPROT', 'TREMBL', 'UNIPARC', 'RefSeq', 'SIFT', 'PolyPhen', 'EXON', 'INTRON', 'DOMAINS', 'GMAF', 'AFR_MAF', 'AMR_MAF', 'ASN_MAF', 'EAS_MAF', 'EUR_MAF', 'SAS_MAF', 'AA_MAF', 'EA_MAF', 'CLIN_SIG', 'SOMATIC', 'PUBMED', 'MOTIF_NAME', 'MOTIF_POS', 'HIGH_INF_POS', 'MOTIF_SCORE_CHANGE', 'IMPACT', 'PICK', 'VARIANT_CLASS', 'TSL', 'HGVS_OFFSET', 'PHENO', 'MINIMISED', 'ExAC_AF', 'ExAC_AF_AFR', 'ExAC_AF_AMR', 'ExAC_AF_EAS', 'ExAC_AF_FIN', 'ExAC_AF_NFE', 'ExAC_AF_OTH', 'ExAC_AF_SAS', 'GENE_PHENO', 'FILTER', 'COSMIC', 'CENTERS', 'CONTEXT', 'DBVS', 'NCALLERS']

# %%
# Define the columns we need for analysis
# Only loading necessary columns reduces memory usage significantly
REQUIRED_COLUMNS = [
    "Hugo_Symbol",  # Gene symbol
    "Chromosome",  # Chromosome location
    "Start_Position",  # Mutation start position
    "Variant_Classification",  # Type of mutation (missense, silent, etc.)
    "Tumor_Sample_Barcode",  # Sample identifier
    "HGVSc",
    "HGVSp",
    "HGVSp_Short",
]

# Load the full MAF file with only the required columns
# Using usecols parameter improves performance by reducing memory footprint
maf = pd.read_csv(MAF_FILE_PATH, sep="\t", usecols=REQUIRED_COLUMNS, low_memory=False)

# %%
# Configuration for GDC API request
GDC_API_SIZE = "20000"  # Maximum number of cases to retrieve
GDC_API_FIELDS = "submitter_id,project.project_id"  # Fields to request

# Fetch case metadata from the GDC (Genomic Data Commons) API
# This provides the mapping between sample barcodes and their cancer project IDs
params = {
    "size": GDC_API_SIZE,
    "fields": GDC_API_FIELDS,
    "format": "JSON",
}

r = requests.get(GDC_CASE_NUMBER_URL, params=params)
hits = r.json()["data"]["hits"]

# Convert the API response into a DataFrame
# Each row contains a case ID and its associated project ID (e.g., TCGA-BRCA)
meta = pd.DataFrame(
    [
        {
            "Tumor_Sample_Barcode": h["submitter_id"],
            "project_id": h["project"]["project_id"],
        }
        for h in hits
    ]
)
meta.head()
# Out:
#   Tumor_Sample_Barcode project_id
# 0    HCM-WCMC-0950-C67  HCMI-CMDC
# 1    HCM-BROD-0682-C64  HCMI-CMDC
# 2    HCM-CSHL-0582-C18  HCMI-CMDC
# 3    HCM-EXPT-1073-C18  HCMI-CMDC
# 4    HCM-BROD-0328-C15  HCMI-CMDC

# %%
# Configuration: Specify which cancer project to extract
TARGET_PROJECT_ID = "TCGA-BRCA"  # TCGA Breast Cancer project
CASE_ID_PREFIX_LENGTH = (
    3  # Number of barcode segments to use for case ID (e.g., TCGA-3C-AALI)
)

# Extract the case ID from the tumor sample barcode
# Tumor_Sample_Barcode format: TCGA-3C-AALI-01A-11D-A41F-09
# Case ID format: TCGA-3C-AALI (first 3 segments separated by hyphens)
maf["case_id"] = (
    maf["Tumor_Sample_Barcode"].str.split("-").str[:CASE_ID_PREFIX_LENGTH].str.join("-")
)

# Prepare metadata for merging by renaming the column
meta = meta.rename(columns={"Tumor_Sample_Barcode": "case_id"})

# Merge MAF data with project metadata to get project IDs for each sample
maf_merged = maf.merge(meta, on="case_id", how="left")

# Filter to keep only the target cancer project (e.g., TCGA-BRCA)
maf_brca = maf_merged[maf_merged["project_id"] == TARGET_PROJECT_ID]

# Save the filtered data to CSV
maf_brca.to_csv(TCGA_BRCA_SAVE_PATH, index=False)

# Display the number of mutations found in the target project
print(f"Total mutations in {TARGET_PROJECT_ID}: {len(maf_brca)}")
len(maf_brca)
# Out:
# Total mutations in TCGA-BRCA: 110492
# 110492

# %%
maf_brca
# Out:
#         Hugo_Symbol Chromosome  Start_Position Variant_Classification  \
# 255156         BTRC         10       103292795                 Silent
# 255157         LDB1         10       103867505                  3'UTR
# 255158        NFKB2         10       104157126      Nonsense_Mutation
# 255159        CELF2         10        11378155                  3'UTR
# 255160        WDR37         10         1175988                  3'UTR
# ...             ...        ...             ...                    ...
# 3580703        IPPK          9        95396703      Missense_Mutation
# 3580704       STAG2          X       123217344      Missense_Mutation
# 3580705          GK          X        30671631                  5'UTR
# 3580706     CXorf67          X        51151398                  3'UTR
# 3580707        PHF8          X        54014379            Splice_Site
#
#                  Tumor_Sample_Barcode       case_id project_id
# 255156   TCGA-3C-AALI-01A-11D-A41F-09  TCGA-3C-AALI  TCGA-BRCA
# 255157   TCGA-3C-AALI-01A-11D-A41F-09  TCGA-3C-AALI  TCGA-BRCA
# 255158   TCGA-3C-AALI-01A-11D-A41F-09  TCGA-3C-AALI  TCGA-BRCA
# 255159   TCGA-3C-AALI-01A-11D-A41F-09  TCGA-3C-AALI  TCGA-BRCA
# 255160   TCGA-3C-AALI-01A-11D-A41F-09  TCGA-3C-AALI  TCGA-BRCA
# ...                               ...           ...        ...
# 3580703  TCGA-Z7-A8R6-01A-11D-A41F-09  TCGA-Z7-A8R6  TCGA-BRCA
# 3580704  TCGA-Z7-A8R6-01A-11D-A41F-09  TCGA-Z7-A8R6  TCGA-BRCA
# 3580705  TCGA-Z7-A8R6-01A-11D-A41F-09  TCGA-Z7-A8R6  TCGA-BRCA
# 3580706  TCGA-Z7-A8R6-01A-11D-A41F-09  TCGA-Z7-A8R6  TCGA-BRCA
# 3580707  TCGA-Z7-A8R6-01A-11D-A41F-09  TCGA-Z7-A8R6  TCGA-BRCA
#
# [110492 rows x 7 columns]

# %%
import re
import pandas as pd

# ----------------------------
# Inputs
# ----------------------------
reactome_path = "/Users/zhangxumeng/Desktop/BIME550_Proj2/BIME550-Project-KR/data/disease_variant_ewas_mapping.tsv"
mc3_path = (
    "/Users/zhangxumeng/Desktop/BIME550_Proj2/BIME550-Project-KR/results/TCGA_BRCA.csv"
)

# ----------------------------
# Load Reactome mutation table
# ----------------------------
map_df = pd.read_csv(reactome_path, sep="\t", dtype=str)

# Keep a minimal set of useful columns (add more if you want)
keep_cols = [
    "Genename",
    "displayName",
    # "stable_id",
    "disease",
    # "disease_identifier",
    # "entityWithAccessionedSequence_pathway_stable_id",
    "entityWithAccessionedSequence_pathway_displayName",
    "entityWithAccessionedSequence_reactionLikeEvent_entityFunctionalStatus_functionalStatus_functionalStatusType_displayName",
]
keep_cols = [c for c in keep_cols if c in map_df.columns]
map_df = map_df[keep_cols].copy()
map_df = map_df[map_df["disease"].str.contains("breast cancer", case=False, na=False)]


# ----------------------------
# Parse protein mutation from displayName
# Example: "ABCA1 W590S [plasma membrane]" -> "W590S" -> "p.W590S"
# ----------------------------
def extract_protein_change_short(display_name: str) -> str:
    if pd.isna(display_name):
        return None
    s = str(display_name)

    # Common patterns in your file:
    #   W590S
    #   R1057*
    #   V2442Sfs*22
    #   T77_L82del
    # We'll grab the token after the first space, before " [" if present.
    # e.g. "ABCA1 W590S [..]" -> "W590S"
    m = re.search(r"^[A-Za-z0-9_-]+\s+([^\s\[]+)", s)
    if not m:
        return None
    mut = m.group(1).strip()

    # Standardize to MC3 HGVSp_Short style: "p.<mutation>"
    return f"p.{mut}"


map_df["HGVSp_Short_like"] = map_df["displayName"].apply(extract_protein_change_short)

# Optional: drop rows where we failed to parse a mutation token
map_df = map_df.dropna(subset=["Genename", "HGVSp_Short_like"])

# Optional: remove duplicate gene+mutation pairs
map_df = map_df.drop_duplicates(subset=["Genename", "HGVSp_Short_like"])

# ----------------------------
# Load MC3 MAF (tab-delimited, gz)
# ----------------------------
maf = pd.read_csv(mc3_path, comment="#", low_memory=False, dtype=str)

# Keep only the columns we need
maf = maf[
    [
        "Hugo_Symbol",
        "Tumor_Sample_Barcode",
        "HGVSp_Short",
        # "HGVSc",
        "Chromosome",
        "Start_Position",
        # "End_Position",
        "Variant_Classification",
        # "Protein_position",
    ]
].copy()

# ----------------------------
# Exact mutation match: (gene + HGVSp_Short)
# ----------------------------
merged_exact = maf.merge(
    map_df,
    right_on=["Genename", "HGVSp_Short_like"],
    left_on=["Hugo_Symbol", "HGVSp_Short"],
    how="inner",
)

print("Exact protein-mutation matches:", merged_exact.shape[0])
merged_exact
# Out:
# Exact protein-mutation matches: 299
#     Hugo_Symbol          Tumor_Sample_Barcode HGVSp_Short Chromosome  \
# 0        PIK3CA  TCGA-3C-AALK-01A-11D-A41F-09     p.E542K          3
# 1        PIK3CA  TCGA-A2-A0D1-01A-11W-A050-09     p.E542K          3
# 2        PIK3CA  TCGA-A2-A0EO-01A-11W-A050-09     p.E542K          3
# 3        PIK3CA  TCGA-A2-A0T7-01A-21D-A099-09     p.E542K          3
# 4        PIK3CA  TCGA-A2-A25A-01A-12D-A16D-09     p.E542K          3
# ..          ...                           ...         ...        ...
# 294       SMAD4  TCGA-D8-A1X9-01A-12D-A159-09     p.E526*         18
# 295       ERBB2  TCGA-D8-A27G-01A-11D-A16D-09     p.I767M         17
# 296         RB1  TCGA-E9-A1RC-01A-11D-A159-09     p.R455*         13
# 297       SMAD4  TCGA-GM-A2D9-01A-11D-A18P-09     p.Q334*         18
# 298        PTEN  TCGA-S3-A6ZH-01A-22D-A32I-09     p.Q149*         10
#
#     Start_Position Variant_Classification Genename  \
# 0        178936082      Missense_Mutation   PIK3CA
# 1        178936082      Missense_Mutation   PIK3CA
# 2        178936082      Missense_Mutation   PIK3CA
# 3        178936082      Missense_Mutation   PIK3CA
# 4        178936082      Missense_Mutation   PIK3CA
# ..             ...                    ...      ...
# 294       48604754      Nonsense_Mutation    SMAD4
# 295       37880257      Missense_Mutation    ERBB2
# 296       48953760      Nonsense_Mutation      RB1
# 297       48591837      Nonsense_Mutation    SMAD4
# 298       89692961      Nonsense_Mutation     PTEN
#
#                             displayName  \
# 0                PIK3CA E542K [cytosol]
# 1                PIK3CA E542K [cytosol]
# 2                PIK3CA E542K [cytosol]
# 3                PIK3CA E542K [cytosol]
# 4                PIK3CA E542K [cytosol]
# ..                                  ...
# 294               SMAD4 E526* [cytosol]
# 295  p-6Y-ERBB2 I767M [plasma membrane]
# 296                 RB1 R455* [cytosol]
# 297               SMAD4 Q334* [cytosol]
# 298                PTEN Q149* [cytosol]
#
#                                                disease  \
# 0    thyroid cancer|breast cancer|head and neck squ...
# 1    thyroid cancer|breast cancer|head and neck squ...
# 2    thyroid cancer|breast cancer|head and neck squ...
# 3    thyroid cancer|breast cancer|head and neck squ...
# 4    thyroid cancer|breast cancer|head and neck squ...
# ..                                                 ...
# 294  cancer|breast cancer|large intestine cancer|ph...
# 295  esophagus squamous cell carcinoma|bladder carc...
# 296  prostate adenocarcinoma|esophagus squamous cel...
# 297  stomach cancer|cancer|breast cancer|skin squam...
# 298  endometrial cancer|cancer|breast cancer|renal ...
#
#      entityWithAccessionedSequence_pathway_displayName  \
# 0    Constitutive Signaling by Aberrant PI3K in Cancer
# 1    Constitutive Signaling by Aberrant PI3K in Cancer
# 2    Constitutive Signaling by Aberrant PI3K in Cancer
# 3    Constitutive Signaling by Aberrant PI3K in Cancer
# 4    Constitutive Signaling by Aberrant PI3K in Cancer
# ..                                                 ...
# 294                 SMAD4 MH2 Domain Mutants in Cancer
# 295                      Signaling by ERBB2 KD Mutants
# 296  Defective translocation of RB1 mutants to the ...
# 297                 SMAD4 MH2 Domain Mutants in Cancer
# 298                    PTEN Loss of Function in Cancer
#
#     entityWithAccessionedSequence_reactionLikeEvent_entityFunctionalStatus_functionalStatus_functionalStatusType_displayName  \
# 0                                     gain_of_function
# 1                                     gain_of_function
# 2                                     gain_of_function
# 3                                     gain_of_function
# 4                                     gain_of_function
# ..                                                 ...
# 294                                   loss_of_function
# 295                                   gain_of_function
# 296          loss_of_function|partial_loss_of_function
# 297                                   loss_of_function
# 298                                   loss_of_function
#
#     HGVSp_Short_like
# 0            p.E542K
# 1            p.E542K
# 2            p.E542K
# 3            p.E542K
# 4            p.E542K
# ..               ...
# 294          p.E526*
# 295          p.I767M
# 296          p.R455*
# 297          p.Q334*
# 298          p.Q149*
#
# [299 rows x 12 columns]

# %%
merged_exact["entityWithAccessionedSequence_pathway_displayName"].unique()
# Out:
# array(['Constitutive Signaling by Aberrant PI3K in Cancer',
#        'Signaling by ERBB2 KD Mutants',
#        'Defective translocation of RB1 mutants to the nucleus',
#        'Signaling by ERBB2 TMD/JMD mutants',
#        'Signaling by ERBB2 ECD mutants',
#        'Constitutive Signaling by AKT1 E17K in Cancer',
#        'Loss of function of TP53 in cancer due to loss of tetramerization ability',
#        'PTEN Loss of Function in Cancer',
#        'SMAD4 MH2 Domain Mutants in Cancer'], dtype=object)

# %%
merged_exact[
    "entityWithAccessionedSequence_reactionLikeEvent_entityFunctionalStatus_functionalStatus_functionalStatusType_displayName"
].unique()
# Out:
# array(['gain_of_function', 'loss_of_function|partial_loss_of_function',
#        'loss_of_function'], dtype=object)

# %%
merged_exact[
    ["Genename", "entityWithAccessionedSequence_pathway_displayName"]
].drop_duplicates()
# Out:
#     Genename  entityWithAccessionedSequence_pathway_displayName
# 0     PIK3CA  Constitutive Signaling by Aberrant PI3K in Cancer
# 36     ERBB2                      Signaling by ERBB2 KD Mutants
# 51       RB1  Defective translocation of RB1 mutants to the ...
# 224    ERBB2                 Signaling by ERBB2 TMD/JMD mutants
# 230    ERBB2                     Signaling by ERBB2 ECD mutants
# 240     AKT1      Constitutive Signaling by AKT1 E17K in Cancer
# 272     TP53  Loss of function of TP53 in cancer due to loss...
# 274     PTEN                    PTEN Loss of Function in Cancer
# 293    SMAD4                 SMAD4 MH2 Domain Mutants in Cancer

# %%
# ----------------------------
# (Optional) Less-strict match: same gene + same protein position
# Useful if exact amino-acid change is too strict
# ----------------------------
def extract_position(hgvsp_short: str) -> str:
    if pd.isna(hgvsp_short):
        return None
    # e.g. p.W590S -> 590 ; p.V2442Sfs*22 -> 2442 ; p.R1057* -> 1057
    m = re.search(r"p\.[A-Za-z\*]+(\d+)", str(hgvsp_short))
    return m.group(1) if m else None


map_df["Protein_position_like"] = map_df["HGVSp_Short_like"].apply(extract_position)

# Only keep parseable positions
map_pos = map_df.dropna(subset=["Genename", "Protein_position_like"]).copy()

merged_pos = maf.dropna(subset=["Hugo_Symbol"]).merge(
    map_pos,
    right_on=["Genename"],
    left_on=["Hugo_Symbol"],
    how="inner",
)

print("Gene + protein-position matches:", len(merged_pos))
merged_pos
# Out:
# Gene + protein-position matches: 12858
#       Hugo_Symbol          Tumor_Sample_Barcode HGVSp_Short Chromosome  \
# 0           PALB2  TCGA-3C-AALI-01A-11D-A41F-09     p.L381V         16
# 1           PALB2  TCGA-3C-AALI-01A-11D-A41F-09     p.L381V         16
# 2           PALB2  TCGA-3C-AALI-01A-11D-A41F-09     p.L381V         16
# 3           PALB2  TCGA-3C-AALI-01A-11D-A41F-09     p.L381V         16
# 4           PALB2  TCGA-3C-AALI-01A-11D-A41F-09     p.L381V         16
# ...           ...                           ...         ...        ...
# 12853         CBL  TCGA-E9-A244-01A-11D-A167-09     p.V813V         11
# 12854        DAXX  TCGA-AN-A046-01A-21W-A050-09     p.D729N          6
# 12855        DAXX  TCGA-AR-A24U-01A-11D-A167-09     p.M381R          6
# 12856        DAXX  TCGA-LD-A74U-01A-13D-A33E-09     p.V348I          6
# 12857        DAXX  TCGA-PE-A5DE-01A-11D-A27P-09     p.L109L          6
#
#       Start_Position Variant_Classification Genename  \
# 0           23646726      Missense_Mutation    PALB2
# 1           23646726      Missense_Mutation    PALB2
# 2           23646726      Missense_Mutation    PALB2
# 3           23646726      Missense_Mutation    PALB2
# 4           23646726      Missense_Mutation    PALB2
# ...              ...                    ...      ...
# 12853      119170209                 Silent      CBL
# 12854       33286558      Missense_Mutation     DAXX
# 12855       33288266      Missense_Mutation     DAXX
# 12856       33288366      Missense_Mutation     DAXX
# 12857       33289225                 Silent     DAXX
#
#                            displayName  \
# 0       PALB2 G1121Vfs*3 [nucleoplasm]
# 1      PALB2 G1166Vfs*25 [nucleoplasm]
# 2      PALB2 Y1108Sfs*16 [nucleoplasm]
# 3       PALB2 N1039Ifs*2 [nucleoplasm]
# 4       PALB2 A995Cfs*16 [nucleoplasm]
# ...                                ...
# 12853              CBL H398R [cytosol]
# 12854         DAXX C106* [nucleoplasm]
# 12855         DAXX C106* [nucleoplasm]
# 12856         DAXX C106* [nucleoplasm]
# 12857         DAXX C106* [nucleoplasm]
#
#                                                  disease  \
# 0                                   cancer|breast cancer
# 1                                   cancer|breast cancer
# 2                                   cancer|breast cancer
# 3                    cancer|Fanconi anemia|breast cancer
# 4                                   cancer|breast cancer
# ...                                                  ...
# 12853  lung adenocarcinoma|melanoma|breast cancer|chr...
# 12854                               cancer|breast cancer
# 12855                               cancer|breast cancer
# 12856                               cancer|breast cancer
# 12857                               cancer|breast cancer
#
#        entityWithAccessionedSequence_pathway_displayName HGVSp_Short_like  \
# 0      Defective HDR through Homologous Recombination...     p.G1121Vfs*3
# 1      Defective HDR through Homologous Recombination...    p.G1166Vfs*25
# 2      Defective HDR through Homologous Recombination...    p.Y1108Sfs*16
# 3      Defective HDR through Homologous Recombination...     p.N1039Ifs*2
# 4      Defective HDR through Homologous Recombination...     p.A995Cfs*16
# ...                                                  ...              ...
# 12853                      FLT3 signaling by CBL mutants          p.H398R
# 12854  Defective Inhibition of DNA Recombination at T...          p.C106*
# 12855  Defective Inhibition of DNA Recombination at T...          p.C106*
# 12856  Defective Inhibition of DNA Recombination at T...          p.C106*
# 12857  Defective Inhibition of DNA Recombination at T...          p.C106*
#
#       Protein_position_like
# 0                      1121
# 1                      1166
# 2                      1108
# 3                      1039
# 4                       995
# ...                     ...
# 12853                   398
# 12854                   106
# 12855                   106
# 12856                   106
# 12857                   106
#
# [12858 rows x 12 columns]
